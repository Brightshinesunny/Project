# %% [markdown]
# <a href="https://colab.research.google.com/github/Brightshinesunny/Project/blob/main/Untitled68.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
biased_points = [
    (1.419, 443.8),
    (1.4425, 338.6),
    (1.478, 191.304)
]
true_point = (1.4, 528.28)

# Plot
fig, ax = plt.subplots(figsize=(5, 5))

# Plot data points
ax.scatter(*zip(*biased_points), color='black', label=r"$(\tilde{\Lambda}^{\rm inf}, m_s^{\rm inf})$")
ax.scatter(*true_point, color='red', label=r"$(\tilde{\Lambda}^{\rm true}, m_s^{\rm true})$")

# Axis settings
ax.set_xlim(1.3, 1.6)
ax.set_ylim(100, 1000)
ax.set_yscale("log")

ax.set_xticks([1.3, 1.4, 1.5])
ax.set_xlabel(r"$m_s\, (M_\odot)$", fontsize=14)
ax.set_ylabel(r"$\tilde{\Lambda}$", fontsize=14)

# Grid
ax.grid(True, which="both", linestyle="--", linewidth=0.5)

# Log ticks formatting
from matplotlib.ticker import LogFormatter
ax.yaxis.set_major_formatter(LogFormatter(base=10))

# Tight layout
plt.tight_layout()
plt.legend()
plt.show()
